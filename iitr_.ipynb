# %% [markdown]
# <a href="https://colab.research.google.com/github/Sparshh15/python-learning/blob/main/iitr_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install afinn

# %%
from afinn import Afinn

# %%
import numpy as np
import pandas as pd

# %%
afinnscore = Afinn()
afinnscore.score("Nice")
# Out:
# 3.0

# %%
afinnscore = Afinn()
afinnscore.score(':):()')
# Out:
# 0.0

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
analyzer =  SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()
analyzer.polarity_scores("this is not a good phone")
# Out:
# {'neg': 0.376, 'neu': 0.624, 'pos': 0.0, 'compound': -0.3412}

# %%
analyzer =  SentimentIntensityAnalyzer()
analyzer.polarity_scores("this is wonderful phone , good battery , awful camera")
# Out:
# {'neg': 0.205, 'neu': 0.342, 'pos': 0.452, 'compound': 0.5574}

# %%
with open('/content/Mankibaat.txt', 'r', encoding='utf-8') as f: text = f.read()
print(f"succesfully loaded ther first 100 characters: \n{text[:100]}..")
# Out:
# succesfully loaded ther first 100 characters:
# ﻿1. October 3,  2014
#
#
# My Dear Countryme
# Today is the holy festival of Vijay Dashami. My heartiest g..

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

print(f"total sentences found: {len(sentences)}")
print(f"first 5 sentences: {sentences[:5]}")
for i , sentence in enumerate(sentences[:5]):
  print(f"sentence {i+1}: {sentence}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# total sentences found: 15317
# first 5 sentences: ['\ufeff1.', 'October 3,  2014\n\n\nMy Dear Countryme\nToday is the holy festival of Vijay Dashami.', 'My heartiest greetings on this occasion of Vijay Dashami to one and all.', 'Through the medium of radio, I would like to share few heartfelt thoughts with you today.', 'And, I hope that not only today, this series of conversation may be carried out regularly in future.']
# sentence 1: ﻿1.
# sentence 2: October 3,  2014
#
#
# My Dear Countryme
# Today is the holy festival of Vijay Dashami.
# sentence 3: My heartiest greetings on this occasion of Vijay Dashami to one and all.
# sentence 4: Through the medium of radio, I would like to share few heartfelt thoughts with you today.
# ...

# %%
sentence_sentiments = []
for sentence in sentences:
  if sentence.strip(): # ensure the sentence is not empty or just whitespafce
      score = analyzer.polarity_scores(sentence)
      sentence_sentiments.append(score)

print(f"calculated sentiments for {len(sentence_sentiments)} sentences")
print("first 5 sentence sentiment scores:")
for i , score in enumerate(sentence_sentiments[:5]):
  print(f"sentence {i+1}: {score}")
# Out:
# calculated sentiments for 15317 sentences
# first 5 sentence sentiment scores:
# sentence 1: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence 2: {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.7003}
# sentence 3: {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.4215}
# sentence 4: {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.802}
# sentence 5: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}

# %%
sentence_sentiment_categories = []
for score_dict in sentence_sentiments:
  compound_score = score_dict['compound']
  if compound_score >= 0.05:
    sentiment_category = 'positive'
  elif compound_score <= -0.05:
    sentiment_category = 'negative'
  else:
    sentiment_category = 'neutral'
  sentence_sentiment_categories.append(sentiment_category)
print(f"calculated sentiments for {len(sentence_sentiment_categories)} sentences")
print("first 10 sentence sentiment categories:")
for i , category in enumerate(sentence_sentiment_categories[:10]):
  print(f"sentence {i+1}: {category}")
# Out:
# calculated sentiments for 15317 sentences
# first 10 sentence sentiment categories:
# sentence 1: neutral
# sentence 2: positive
# sentence 3: positive
# sentence 4: positive
# sentence 5: positive
# sentence 6: positive
# sentence 7: neutral
# sentence 8: positive
# sentence 9: positive
# sentence 10: negative
